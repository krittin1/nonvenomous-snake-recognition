# %%
import cv2

import numpy as np
import os
from random import shuffle
from tqdm import tqdm
from keras.preprocessing.image import ImageDataGenerator

TRAIN_DIR ='C:/Users/Khan/Desktop/All File/Untitled Folder 1/train'
TEST_DIR ='C:/Users/Khan/Desktop/All File/Untitled Folder 1/test'
IMG_SIZE = 50
LR = 1e-3
MODEL_NAME = 'dogsvscats-{}-{}.model'.format(LR, '2conv-basic') # just so we remember which saved model is which, sizes must match
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-04dab06a1966> in <module>
#       1 import cv2
# ----> 2 import tensorflow as tf
#       3 import numpy as np
#       4 import os
#       5 from random import shuffle
#
# ~\Anaconda3\lib\site-packages\tensorflow\__init__.py in <module>
#      26
#      27 # pylint: disable=g-bad-import-order
# ---> 28 from tensorflow.python import pywrap_tensorflow  # pylint: disable=unused-import
#      29 from tensorflow.python.tools import module_util as _module_util
#      30
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\__init__.py in <module>
#      81 from tensorflow.python import data
#      82 from tensorflow.python import distribute
# ---> 83 from tensorflow.python import keras
#      84 from tensorflow.python.feature_column import feature_column_lib as feature_column
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-64156d691fe5> in <module>
# ----> 1 import tensorflow as tf
#
# ~\Anaconda3\lib\site-packages\tensorflow\__init__.py in <module>
#      26
#      27 # pylint: disable=g-bad-import-order
# ---> 28 from tensorflow.python import pywrap_tensorflow  # pylint: disable=unused-import
#      29 from tensorflow.python.tools import module_util as _module_util
#      30
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\__init__.py in <module>
#      81 from tensorflow.python import data
#      82 from tensorflow.python import distribute
# ---> 83 from tensorflow.python import keras
#      84 from tensorflow.python.feature_column import feature_column_lib as feature_column
#      85 from tensorflow.python.layers import layers
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\__init__.py in <module>
#      25
# ...

# %%
def label_img(img):
    word_label =img.split('.')[-3]
    if word_label =='venom':return [1,0] #มีพิษ

    elif word_label =='harmless':return [0,1] #ไม่มีพิษ

# %%
def create_train_data():  ##สร้างเทรน
        training_data=[]
        for img in tqdm(os.listdir(TRAIN_DIR)):
            label = label_img(img) ## แยก.jpg ใน label
            path = os.path.join(TRAIN_DIR,img)## เปิดรูปไฟล์รูป
            img = cv2.imread(path,cv2.IMREAD_COLOR) #อ่านรูปภาพ
            img = cv2.resize(img,(IMG_SIZE,IMG_SIZE))# ย่อขนาดให้เหลือ 50*50
            training_data.append ([np.array(img),np.array(label)]) ## เอาเข้า array
        shuffle(training_data) # สับ data เพื่อไม่ให้ overfit ทำให้ data มีความยืดยุ่น
        np.save('train_data.npy',training_data) #save
        return training_data

# %%
def process_test_data(): ##เอาไว้เทสยังไม่ได้ลอง
        tesing_data =[] 
        for img in tqdm(os.listdir(TEST_DIR)):# วนลูปเอารูปทุกรูปในโฟเดอ์
            path = os.path.join(TEST_DIR,img)
            img = cv2.imread(path,cv2.IMREAD_COLOR)
            img = cv2.resize(img,(IMG_SIZE,IMG_SIZE))
            testing_data.append([np.array(img),img_num])

# %%
train_data = create_train_data()

# %%
from keras.models import Sequential
from keras.layers import Conv2D,Dense, Flatten, MaxPooling2D
from keras.layers import Activation ,Dropout
import easygui
from sklearn.metrics import classification_report

# %%
snake= Sequential()# เรียกใช้ model

snake.add(Conv2D(32, (3, 3), input_shape = (IMG_SIZE, IMG_SIZE, 3)))
snake.add(Activation('relu'))
snake.add(MaxPooling2D(pool_size=(2,2)))

snake.add(Conv2D(32, (3, 3) ))
snake.add(Activation('relu'))
snake.add(MaxPooling2D(pool_size=(2,2)))

snake.add(Conv2D(64, (3, 3)))
snake.add(Activation('relu'))
snake.add(MaxPooling2D(pool_size=(2, 2)))

snake.add(Flatten())
snake.add(Dense(32))
snake.add(Activation('relu'))
snake.add(Dropout(0.5))
snake.add(Dense(1))
snake.add(Activation('sigmoid'))

snake.compile(loss='categorical_crossentropy',
              optimizer='adam',
          
              metrics=['accuracy'])


train = train_data[:-500]
# test = train_data[-500:]


snake.summary()
# snake.save(train_data.npy)

# %%
X = np.array([i[0] for i in train]).reshape(-1,IMG_SIZE,IMG_SIZE,1)
Y = [i[1] for i in train]

test_x = np.array([i[0] for i in test]).reshape(-1,IMG_SIZE,IMG_SIZE,1)
test_y = [i[1] for i in test] #งู มีพิษไม่มีพิษ return เป็น 1,0\0,1

# %%
# snake.load('train_data.npy') 
#if already build model

# %%
from easygui import *
from keras.preprocessing import image

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

while True:
    title="Venom and non-venom"
    msg="predict your pic"
    choices = ["Predict", "Quit"]
    choice = easygui.choicebox(msg, title, choices)
    if choice == "Predict":
         filename = easygui.fileopenbox()
         imgg = image.load_img(filename,grayscale=False, color_mode='rgb', target_size=(IMG_SIZE,IMG_SIZE))
         sn = image.img_to_array(imgg)
         snaketype  = snake.predict_classes(sn.reshape((1,IMG_SIZE, IMG_SIZE,3)),batch_size=32)
         print(snaketype)
    #      snake.evaluate(Y, X)
         if snaketype == [[0]]:
             easygui.msgbox("venom")
         else:
             easygui.msgbox("non-venom")
    else:
            os.exit()
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-4dad8f711379> in <module>
#       1 from easygui import *
# ----> 2 from keras.preprocessing import image
#       3
#       4 from sklearn.model_selection import train_test_split
#       5 from sklearn.metrics import accuracy_score, classification_report
#
# ~\Anaconda3\lib\site-packages\keras\__init__.py in <module>
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# ~\Anaconda3\lib\site-packages\keras\utils\__init__.py in <module>
#       4 from . import data_utils
#       5 from . import io_utils
# ----> 6 from . import conv_utils
#       7
#       8 # Globally-importable utils.
#
# ~\Anaconda3\lib\site-packages\keras\utils\conv_utils.py in <module>
# ...
